# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('All_Pokemon.csv')

# %%
#df=df.drop(['Abilities', 'HP', 'Att', 'Def','Spa', 'Spd', 'Spe','Final Evolution','Experience type'], axis=1)

# %%
df.head(195)
# Out:
#      Number           Name   Type 1    Type 2                      Abilities  \
# 0         1      Bulbasaur    Grass    Poison    ['Chlorophyll', 'Overgrow']
# 1         2        Ivysaur    Grass    Poison    ['Chlorophyll', 'Overgrow']
# 2         3       Venusaur    Grass    Poison    ['Chlorophyll', 'Overgrow']
# 3         3  Mega Venusaur    Grass    Poison                  ['Thick Fat']
# 4         4     Charmander     Fire       NaN       ['Blaze', 'Solar Power']
# ..      ...            ...      ...       ...                            ...
# 190     149      Dragonite   Dragon    Flying  ['Inner Focus', 'Multiscale']
# 191     150         Mewtwo  Psychic       NaN        ['Pressure', 'Unnerve']
# 192     150  Mega Mewtwo Y  Psychic       NaN                   ['Insomnia']
# 193     150  Mega Mewtwo X  Psychic  Fighting                  ['Steadfast']
# 194     151            Mew  Psychic       NaN                ['Synchronize']
#
# ...

# %%
df.describe()
# Out:
#             Number           HP          Att          Def          Spa  \
# count  1032.000000  1032.000000  1032.000000  1032.000000  1032.000000
# mean    439.226744    69.906008    80.526163    74.609496    72.918605
# std     261.871350    26.189155    32.542374    30.905972    32.773495
# min       1.000000     1.000000     5.000000     5.000000    10.000000
# 25%     211.750000    50.000000    55.000000    50.000000    50.000000
# 50%     434.500000    67.000000    78.000000    70.000000    65.000000
# 75%     667.250000    83.000000   100.000000    90.000000    95.000000
# max     898.000000   255.000000   190.000000   230.000000   194.000000
#
#                Spd          Spe          BST         Mean  Standard Deviation  \
# count  1032.000000  1032.000000  1032.000000  1032.000000         1032.000000
# mean     72.139535    68.548450   438.648256    73.108043           20.028104
# std      27.625876    30.219526   120.675545    20.112591           10.830298
# ...

# %%
df.columns
# Out:
# Index(['Number', 'Name', 'Type 1', 'Type 2', 'Abilities', 'HP', 'Att', 'Def',
#        'Spa', 'Spd', 'Spe', 'BST', 'Mean', 'Standard Deviation', 'Generation',
#        'Experience type', 'Experience to level 100', 'Final Evolution',
#        'Catch Rate', 'Legendary', 'Mega Evolution', 'Alolan Form',
#        'Galarian Form', 'Against Normal', 'Against Fire', 'Against Water',
#        'Against Electric', 'Against Grass', 'Against Ice', 'Against Fighting',
#        'Against Poison', 'Against Ground', 'Against Flying', 'Against Psychic',
#        'Against Bug', 'Against Rock', 'Against Ghost', 'Against Dragon',
#        'Against Dark', 'Against Steel', 'Against Fairy', 'Height', 'Weight',
#        'BMI'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Number                       0
# Name                         0
# Type 1                       0
# Type 2                     484
# Abilities                    0
# HP                           0
# Att                          0
# Def                          0
# Spa                          0
# Spd                          0
# Spe                          0
# BST                          0
# Mean                         0
# Standard Deviation           0
# Generation                   0
# Experience type              0
# Experience to level 100      0
# Final Evolution              0
# Catch Rate                   0
# Legendary                    0
# Mega Evolution               0
# Alolan Form                  0
# Galarian Form                0
# Against Normal               0
# Against Fire                 0
# Against Water                0
# Against Electric             0
# Against Grass                0
# Against Ice                  0
# Against Fighting             0
# ...

# %%
df.nunique()
# Out:
# Number                      898
# Name                       1032
# Type 1                       18
# Type 2                       18
# Abilities                   602
# HP                          103
# Att                         123
# Def                         113
# Spa                         119
# Spd                         106
# Spe                         127
# BST                         215
# Mean                        215
# Standard Deviation          725
# Generation                    8
# Experience type               6
# Experience to level 100       6
# Final Evolution               2
# Catch Rate                   34
# Legendary                     2
# Mega Evolution                2
# Alolan Form                   2
# Galarian Form                 2
# Against Normal                4
# Against Fire                  5
# Against Water                 5
# Against Electric              6
# Against Grass                 5
# Against Ice                   5
# ...

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       131
# Normal      114
# Grass        91
# Bug          81
# Psychic      77
# Fire         64
# Rock         59
# Electric     59
# Dark         46
# Dragon       42
# Fighting     42
# Ground       41
# Ghost        41
# Poison       40
# Ice          38
# Steel        36
# Fairy        22
# Flying        8
# Name: count, dtype: int64

# %%
labels = ['Water', 'Normal', 'Grass', 'Bug', 'Psychic', 'Fire', 'Rock', 'Electric', 'Dark', 'Dragon',
          'Fighting', 'Ground', 'Ghost', 'Poison', 'Ice', 'Steel', 'Fairy', 'Flying']
sizes = [131, 114, 91, 81, 77, 64, 59, 59, 46, 42, 42, 41, 41, 40, 38, 36, 22, 8]
colors = ['blue', 'orange', 'green', 'brown', 'purple', 'red', 'gray', 'yellow', 'darkslategray','darkviolet', 'sienna', 'burlywood', 'slategray', 'darkolivegreen', 'lightblue', 'pink', 'lightcoral']

plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=90)

plt.title("Percentage of Different Types of Pokemon")

plt.show()

# %%
df['Type 2'].value_counts()
# Out:
# Type 2
# Flying      112
# Psychic      42
# Fairy        41
# Ground       39
# Poison       37
# Steel        35
# Fighting     31
# Dragon       30
# Grass        28
# Ghost        27
# Dark         26
# Water        20
# Ice          18
# Fire         17
# Rock         15
# Electric     11
# Normal       10
# Bug           9
# Name: count, dtype: int64

# %%
labels = ['Flying', 'Psychic', 'Fairy', 'Ground', 'Poison', 'Steel', 'Fighting', 'Dragon',
          'Grass', 'Ghost', 'Dark', 'Water', 'Ice', 'Fire', 'Rock', 'Electric', 'Normal', 'Bug']
sizes = [112, 42, 41, 39, 37, 35, 31, 30, 28, 27, 26, 20, 18, 17, 15, 11, 10, 9]
colors = ['lightblue', 'purple', 'pink', 'saddlebrown', 'darkslategray', 'lightsteelblue',
          'darkorange', 'darkviolet', 'limegreen', 'darkgrey', 'black', 'royalblue', 'deepskyblue',
          'tomato', 'slategray', 'gold', 'gray', 'olive']

plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("Percentage of Different Type 2 Pokemon")

plt.show()

# %%
num_cols=['Number', 'Name', 'Type 1', 'Type 2', 'Abilities', 'HP', 'Att', 'Def',
       'Spa', 'Spd', 'Spe', 'BST', 'Mean', 'Standard Deviation', 'Generation',
       'Experience type', 'Experience to level 100', 'Final Evolution',
       'Catch Rate', 'Legendary', 'Mega Evolution', 'Alolan Form',
       'Galarian Form', 'Against Normal', 'Against Fire', 'Against Water',
       'Against Electric', 'Against Grass', 'Against Ice', 'Against Fighting',
       'Against Poison', 'Against Ground', 'Against Flying', 'Against Psychic',
       'Against Bug', 'Against Rock', 'Against Ghost', 'Against Dragon',
       'Against Dark', 'Against Steel', 'Against Fairy', 'Height', 'Weight',
       'BMI']

# %%
plt.figure(figsize = (30, 30))

for j, col in enumerate(num_cols):
    plt.subplot(8, 8, j+1)
    sns.histplot(data = df, x = col)
    plt.subplots_adjust(left = 0.1,
                    bottom = 0.1, 
                    right = 0.9, 
                    top = 0.9, 
                    wspace = 0.4, 
                    hspace = 0.4) 
    plt.xticks(rotation = 45, horizontalalignment = 'right')

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 1", y = "HP")
plt.ylabel("HP")
plt.xlabel("Type 1")
plt.title('Distribution of HP stat by Type 1')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 2", y = "HP")
plt.ylabel("HP")
plt.xlabel("Type 2")
plt.title('Distribution of HP stat by Type 2')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 1", y = "Att")
plt.ylabel("ATT")
plt.xlabel("Type 1")
plt.title('Distribution of Att stat by Type 1')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 2", y = "Att")
plt.ylabel("ATT")
plt.xlabel("Type 2")
plt.title('Distribution of Att stat by Type 2')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 1", y = "Def")
plt.ylabel("DEF")
plt.xlabel("Type 1")
plt.title('Distribution of Def stat by Type 1')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 2", y = "Def")
plt.ylabel("DEF")
plt.xlabel("Type 2")
plt.title('Distribution of def stat by Type 2')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 1", y = "Spe")
plt.ylabel("SPE")
plt.xlabel("Type 1")
plt.title('Distribution of speed stat by Type 1')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 2", y = "Spe")
plt.ylabel("SPE")
plt.xlabel("Type 2")
plt.title('Distribution of Speed stat by Type 2')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 1", y = "Spa")
plt.ylabel("SPA")
plt.xlabel("Type 1")
plt.title('Distribution of spa stat by Type 1')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 2", y = "Spa")
plt.ylabel("SPA")
plt.xlabel("Type 2")
plt.title('Distribution of spa stat by Type 2')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 1", y = "Spd")
plt.ylabel("SPD")
plt.xlabel("Type 1")
plt.title('Distribution of Spd stat by Type 1')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 2", y = "Spd")
plt.ylabel("SPD")
plt.xlabel("Type 2")
plt.title('Distribution of spd stat by Type 2')
plt.ylim(0, 300)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 1", y = "BST")
plt.ylabel("BST")
plt.xlabel("Type 1")
plt.title('Distribution of BST stat by Type 1')
plt.ylim(0, 800)

plt.show()

# %%
plt.subplots(figsize = (15, 10))

sns.boxplot(data = df, x = "Type 2", y = "BST")
plt.ylabel("BST")
plt.xlabel("Type 2")
plt.title('Distribution of BST stat by Type 2')
plt.ylim(0, 800)

plt.show()

# %%
df[df['Legendary'] == 1.0]
# Out:
#                       Number    Type 1  Type 2                   Abilities  \
# Name
# Articuno                 144       Ice  Flying  ['Pressure', 'Snow Cloak']
# Galarian Articuno        144   Psychic  Flying             ['Competitive']
# Zapdos                   145  Electric  Flying      ['Pressure', 'Static']
# Galarian Zapdos          145  Fighting  Flying                 ['Defiant']
# Moltres                  146      Fire  Flying  ['Flame Body', 'Pressure']
# ...                      ...       ...     ...                         ...
# Glastrier                896       Ice     NaN          ['Chilling Neigh']
# Spectrier                897     Ghost     NaN              ['Grim Neigh']
# Calyrex                  898   Psychic   Grass                 ['Unnerve']
# Calyrex Ice Rider        898   Psychic     Ice                  ['As One']
# Calyrex Shadow Rider     898   Psychic   Ghost                  ['As One']
#
# ...

# %%
df[df['Alolan Form'] == 1.0]
# Out:
#                   Number    Type 1    Type 2  \
# Name
# Alolan Rattata        19      Dark    Normal
# Alolan Raticate       20      Dark    Normal
# Alolan Raichu         26  Electric   Psychic
# Alolan Sandshrew      27       Ice     Steel
# Alolan Sandslash      28       Ice     Steel
# Alolan Vulpix         37       Ice       NaN
# Alolan Ninetales      38       Ice     Fairy
# Alolan Diglett        50    Ground     Steel
# Alolan Dugtrio        51    Ground     Steel
# Alolan Meowth         52      Dark       NaN
# Alolan Persian        53      Dark       NaN
# Alolan Geodude        74      Rock  Electric
# Alolan Graveler       75      Rock  Electric
# Alolan Golem          76      Rock  Electric
# Alolan Grimer         88    Poison      Dark
# Alolan Muk            89    Poison      Dark
# Alolan Exeggutor     103     Grass    Dragon
# Alolan Marowak       105      Fire     Ghost
#
#                                                          Abilities   HP  Att  \
# Name
# ...

# %%
df[df['Galarian Form'] == 1.0]
# Out:
#                               Number    Type 1   Type 2  \
# Name
# Galarian Meowth                   52     Steel      NaN
# Galarian Ponyta                   77   Psychic      NaN
# Galarian Rapidash                 78   Psychic    Fairy
# Galarian Slowpoke                 79   Psychic      NaN
# Galarian Slowbro                  80    Poison  Psychic
# Galarian Farfetch'd               83  Fighting      NaN
# Galarian Weezing                 110    Poison    Fairy
# Galarian Mr. Mime                122       Ice  Psychic
# Galarian Articuno                144   Psychic   Flying
# Galarian Zapdos                  145  Fighting   Flying
# Galarian Moltres                 146      Dark   Flying
# Galarian Slowking                199    Poison  Psychic
# Galarian Corsola                 222     Ghost      NaN
# Galarian Zigzagoon               263      Dark   Normal
# Galarian Linoone                 264      Dark   Normal
# Galarian Darumaka                554       Ice      NaN
# ...

# %%
df[df['Name'].str.contains("Mega ", case = False, na = False)]
# Out:
#      Number              Name    Type 1    Type 2          Abilities   HP  \
# 3         3     Mega Venusaur     Grass    Poison      ['Thick Fat']   80
# 7         6  Mega Charizard Y      Fire    Flying        ['Drought']   78
# 8         6  Mega Charizard X      Fire    Dragon    ['Tough Claws']   78
# 12        9    Mega Blastoise     Water       NaN  ['Mega Launcher']   79
# 19       15     Mega Beedrill       Bug    Poison   ['Adaptability']   65
# 23       18      Mega Pidgeot    Normal    Flying       ['No Guard']   83
# 83       65     Mega Alakazam   Psychic       NaN          ['Trace']   55
# 105      80      Mega Slowbro     Water   Psychic    ['Shell Armor']   95
# 124      94       Mega Gengar     Ghost    Poison     ['Shadow Tag']   60
# 149     115   Mega Kangaskhan    Normal       NaN  ['Parental Bond']  105
# 163     127       Mega Pinsir       Bug    Flying       ['Aerilate']   65
# 167     130     Mega Gyarados     Water      Dark   ['Mold Breaker']   95
# ...

# %%
#Strongest mons
df.sort_values('BST',ascending=False).head(10)
# Out:
#                           Number    Type 1    Type 2  \
# Name
# Mega Mewtwo Y                150   Psychic       NaN
# Mega Mewtwo X                150   Psychic  Fighting
# Mega Rayquaza                384    Dragon    Flying
# Primal Groudon               383    Ground      Fire
# Primal Kyogre                382     Water       NaN
# Ultra Necrozma               800   Psychic    Dragon
# Arceus                       493    Normal       NaN
# Zacian Crowned Sword         888     Fairy     Steel
# Zamazenta Crowned Shield     889  Fighting     Steel
# Zygarde Complete             718    Dragon    Ground
#
#                                                   Abilities   HP  Att  Def  \
# Name
# Mega Mewtwo Y                                  ['Insomnia']  106  150   70
# Mega Mewtwo X                                 ['Steadfast']  106  190  100
# Mega Rayquaza                              ['Delta Stream']  105  180  100
# ...

# %%
#Weakest mons
df.sort_values('BST',ascending=False).tail(10)
# Out:
#             Number   Type 1  Type 2  \
# Name
# Ralts          280  Psychic   Fairy
# Caterpie        10      Bug     NaN
# Wurmple        265      Bug     NaN
# Weedle          13      Bug  Poison
# Kricketot      401      Bug     NaN
# Azurill        298   Normal   Fairy
# Snom           872      Ice     Bug
# Blipbug        824      Bug     NaN
# Sunkern        191    Grass     NaN
# Wishiwashi     746    Water     NaN
#
#                                                Abilities  HP  Att  Def  Spa  \
# Name
# Ralts              ['Synchronize', 'Telepathy', 'Trace']  28   25   25   45
# Caterpie                     ['Run Away', 'Shield Dust']  45   30   35   20
# Wurmple                      ['Run Away', 'Shield Dust']  45   45   35   20
# Weedle                       ['Run Away', 'Shield Dust']  40   35   30   20
# Kricketot                      ['Run Away', 'Shed Skin']  37   25   41   25
# Azurill        ['Huge Power', 'Sap Sipper', 'Thick Fat']  50   20   40   20
# ...

# %%
df= df.set_index('Name')

# %%
a=df['HP'].idxmax()
b=df['HP'].max()
print(a)
print(b)
# Out:
# Blissey
# 255

# %%
a=df['Att'].idxmax()
b=df['Att'].max()
print(a)
print(b)
# Out:
# Mega Mewtwo X
# 190

# %%
a=df['Def'].idxmax()
b=df['Def'].max()
print(a)
print(b)
# Out:
# Mega Steelix
# 230

# %%
a=df['Spe'].idxmax()
b=df['Spe'].max()
print(a)
print(b)
# Out:
# Regieleki
# 200

# %%
a=df['Spa'].idxmax()
b=df['Spa'].max()
print(a)
print(b)
# Out:
# Mega Mewtwo Y
# 194

# %%
a=df['Spd'].idxmax()
b=df['Spd'].max()
print(a)
print(b)
# Out:
# Shuckle
# 230

# %%
a=df['BST'].idxmax()
b=df['BST'].max()
print(a)
print(b)
# Out:
# Mega Mewtwo Y
# 780

# %%
df1=df.drop(['Name','Type 1', 'Type 2', 'Abilities', 'Generation','Experience to level 100', 'Experience type'],axis=1)

# %%
correlation = round(df1.corr(), 2)
correlation
# Out:
#                     Number    HP   Att   Def   Spa   Spd   Spe   BST  Mean  \
# Number                1.00  0.11  0.12  0.09  0.09  0.08  0.02  0.13  0.13
# HP                    0.11  1.00  0.45  0.27  0.37  0.36  0.18  0.64  0.64
# Att                   0.12  0.45  1.00  0.46  0.37  0.27  0.38  0.74  0.74
# Def                   0.09  0.27  0.46  1.00  0.22  0.53 -0.01  0.62  0.62
# Spa                   0.09  0.37  0.37  0.22  1.00  0.51  0.44  0.74  0.74
# Spd                   0.08  0.36  0.27  0.53  0.51  1.00  0.22  0.71  0.71
# Spe                   0.02  0.18  0.38 -0.01  0.44  0.22  1.00  0.56  0.56
# BST                   0.13  0.64  0.74  0.62  0.74  0.71  0.56  1.00  1.00
# Mean                  0.13  0.64  0.74  0.62  0.74  0.71  0.56  1.00  1.00
# Standard Deviation    0.03  0.32  0.34  0.45  0.20  0.35  0.05  0.42  0.42
# Final Evolution       0.06  0.52  0.55  0.48  0.54  0.58  0.44  0.78  0.78
# ...

# %%
plt.figure(figsize = (25, 15))

sns.heatmap(round(df1.corr(), 2), annot = True, cmap = 'vlag', center = 0)
plt.title("Correlation Heatmap df_pokemon")

plt.show()

# %%
b=df['Generation'].unique()
b.sort()

# %%
a=df['Generation'].value_counts().sort_index()
count = [a.iloc[i] for i in range(len(a))]
count
# Out:
# [151, 100, 138, 116, 163, 133, 116, 115]

# %%
plt.plot(b, count, marker='o', color='green', linestyle='-')

# Adding labels and title
plt.xlabel('Generation')
plt.ylabel('Count')
plt.title('Count of Pokemon in Each Generation')

# Display the plot
plt.show()

# %%
leg_filt1 = df[df['Legendary'] == 1]['Type 1'].value_counts()
leg_filt1
# Out:
# Type 1
# Psychic     30
# Dragon      16
# Electric     8
# Water        8
# Steel        8
# Fighting     7
# Fire         6
# Rock         6
# Normal       6
# Dark         5
# Grass        5
# Ground       4
# Bug          3
# Fairy        3
# Ice          3
# Poison       3
# Flying       2
# Ghost        2
# Name: count, dtype: int64

# %%
leg_filt2 = df[df['Legendary'] == 1]['Type 2'].value_counts()
leg_filt2
# Out:
# Type 2
# Flying      17
# Fighting     8
# Steel        8
# Dragon       7
# Ghost        7
# Fairy        7
# Psychic      6
# Ice          4
# Grass        3
# Fire         3
# Ground       3
# Dark         2
# Water        2
# Electric     1
# Poison       1
# Name: count, dtype: int64
